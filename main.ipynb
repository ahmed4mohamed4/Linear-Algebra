# %% [markdown]
# # Lecture 1:
# ## Geometry of Linear Equations
# [Link](https://youtu.be/J7DzL2_Na80?si=BvS_of91ZXQL22Q0)

# %% [markdown]
# ### Notes:
# <image src="./images/1.jpg" alt="Page 1" width="600" height="600"/>
# <image src="./images/2.jpg" alt="Page 2" width="600" height="600"/>
# <image src="./images/3.jpg" alt="Page 3" width="600" height="600"/>
# <image src="./images/4.jpg" alt="Page 4" width="600" height="600"/>
# <image src="./images/5.jpg" alt="Page 5" width="600" height="600"/>
